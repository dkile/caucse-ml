# %% [markdown]
# # K-means clustering

# %% [markdown]
# ## import library

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from matplotlib import cm

# %% [markdown]
# ## load data

# %%
fname_data = 'assignment_11_data.csv'

feature = np.genfromtxt(fname_data, delimiter=',')

x = feature[:,0]
y = feature[:,1]

number_data     = np.size(feature, 0)
number_feature  = np.size(feature, 1)

print('number of data : {}'.format(number_data))
print('number of feature : {}'.format(number_feature))
# Out:
# number of data : 1000
# number of feature : 2

# %% [markdown]
# ## plot the input data

# %%
plt.figure(figsize=(8,8))   
plt.title('input data')

plt.scatter(x, y, color='blue')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## compute distance
# - feature : $n \times m$, center : $1 \times m$, distance : $n \times 1$
# - $n$ : number of data, $m$ : number of features

# %%
def compute_distance(feature, center):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #

    distance = np.linalg.norm(feature - center, axis=1)

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return distance

# %% [markdown]
# ## compute centroid
# - feature : $n \times m$, label_feature : $n \times 1$, value_label : $1 \times 1$, centroid : $1 \times m$
# - $n$ : number of data, $m$ : number of features

# %%
def compute_centroid(feature, label_feature, label):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    centroid = np.zeros(shape=np.size(feature, 1))
    isEmpty = np.sum([label_feature == label]) == 0
    if not isEmpty:
        centroid = np.mean(feature[label_feature == label], axis = 0)
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return isEmpty, centroid

# %% [markdown]
# ## compute label
# - distance : $n \times k$, label_feature : $n \times 1$
# - $n$ : number of data, $k$ : number of clusters

# %%
def compute_label(distance):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    label_feature = np.argmin(distance, axis = 1)

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    
    return label_feature

# %%
def compute_loss(feature, centers, label_feature, num_cluster):
    loss = 0
    for i in range(num_cluster):
        loss += np.sum(np.power(compute_distance(feature[label_feature==i], centers[i]), 2))
    return loss / np.size(feature, 0)

# %% [markdown]
# ## the number of clusters $K = 2$

# %%
number_cluster          = 2
number_iteration        = 1000     # you can modify this value
loss_iteration_02       = np.zeros(number_iteration)
centroid_iteration_02   = np.zeros((number_iteration, number_cluster, number_feature))
label_feature_02        = np.random.randint(0, number_cluster, size=(number_data))

# %%
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# complete the blanks
#
for i in range(number_iteration):
    
    distance_cluster = np.zeros(shape=(number_data, number_cluster))
    
    for cluster_num in range(number_cluster):
        isEmpty, centroid = compute_centroid(feature, label_feature_02, cluster_num)
        if not isEmpty:
            centroid_iteration_02[i][cluster_num] = centroid
        else:
            centroid_iteration_02[i][cluster_num] = centroid_iteration_02[i-1][cluster_num]
        distance_cluster[:,cluster_num] = compute_distance(feature, centroid)
    
    label_feature_02 = compute_label(distance_cluster)
    
    loss = compute_loss(feature, centroid_iteration_02[i], label_feature_02, number_cluster)
    
    loss_iteration_02[i] = loss
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ## the number of clusters $K = 4$

# %%
number_cluster          = 4
number_iteration        = 1000     # you can modify this value
loss_iteration_04       = np.zeros(number_iteration)
centroid_iteration_04   = np.zeros((number_iteration, number_cluster, number_feature))
label_feature_04        = np.random.randint(0, number_cluster, size=(number_data))

# %%
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# complete the blanks
#
for i in range(number_iteration):
    
    distance_cluster = np.zeros(shape=(number_data, number_cluster))
    
    for cluster_num in range(number_cluster):
        isEmpty, centroid = compute_centroid(feature, label_feature_04, cluster_num)
        if not isEmpty:
            centroid_iteration_04[i][cluster_num] = centroid
        else:
            centroid_iteration_04[i][cluster_num] = centroid_iteration_04[i-1][cluster_num]
        distance_cluster[:,cluster_num] = compute_distance(feature, centroid)
    
    label_feature_04 = compute_label(distance_cluster)
    
    loss = compute_loss(feature, centroid_iteration_04[i], label_feature_04, number_cluster)
    
    loss_iteration_04[i] = loss

#
# ++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ## the number of clusters $K = 8$

# %%
number_cluster          = 8
number_iteration        = 10000    # you can modify this value
loss_iteration_08       = np.zeros(number_iteration)
centroid_iteration_08   = np.zeros((number_iteration, number_cluster, number_feature))
label_feature_08        = np.random.randint(0, number_cluster, size=(number_data))

# %%
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# complete the blanks
#
for i in range(number_iteration):
    
    distance_cluster = np.zeros(shape=(number_data, number_cluster))
    
    for cluster_num in range(number_cluster):
        isEmpty, centroid = compute_centroid(feature, label_feature_08, cluster_num)
        if not isEmpty:
            centroid_iteration_08[i][cluster_num] = centroid
        else:
            centroid_iteration_08[i][cluster_num] = centroid_iteration_08[i-1][cluster_num]
        distance_cluster[:,cluster_num] = compute_distance(feature, centroid)
    
    label_feature_08 = compute_label(distance_cluster)
    
    loss = compute_loss(feature, centroid_iteration_08[i], label_feature_08, number_cluster)
    
    loss_iteration_08[i] = loss

#
# ++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ## the number of clusters $K = 16$

# %%
number_cluster          = 16
number_iteration        = 100000    # you can modify this value
loss_iteration_16       = np.zeros(number_iteration)
centroid_iteration_16   = np.zeros((number_iteration, number_cluster, number_feature))
label_feature_16        = np.random.randint(0, number_cluster, size=(number_data))

# %%
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# complete the blanks
#
for i in range(number_iteration):
    
    distance_cluster = np.zeros(shape=(number_data, number_cluster))
    
    for cluster_num in range(number_cluster):
        isEmpty, centroid = compute_centroid(feature, label_feature_16, cluster_num)
        if not isEmpty:
            centroid_iteration_16[i][cluster_num] = centroid
        else:
            centroid_iteration_16[i][cluster_num] = centroid_iteration_16[i-1][cluster_num]
        distance_cluster[:,cluster_num] = compute_distance(feature, centroid)
    
    label_feature_16 = compute_label(distance_cluster)
    
    loss = compute_loss(feature, centroid_iteration_16[i], label_feature_16, number_cluster)
    
    loss_iteration_16[i] = loss

#
# ++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## functions for presenting the results

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
def function_result_01():

    print("final loss (K=2) = {:13.10f}".format(loss_iteration_02[-1]))

# %%
def function_result_02():

    print("final loss (K=4) = {:13.10f}".format(loss_iteration_04[-1]))

# %%
def function_result_03():

    print("final loss (K=8) = {:13.10f}".format(loss_iteration_08[-1]))

# %%
def function_result_04():

    print("final loss (K=16) = {:13.10f}".format(loss_iteration_16[-1]))

# %%
def function_result_05():
    
    plt.figure(figsize=(8,6)) 
    plt.title('loss (K=2)')

    plt.plot(loss_iteration_02, '-', color='red')
    plt.xlabel('iteration')
    plt.ylabel('loss')
    
    plt.tight_layout()
    plt.show()

# %%
def function_result_06():
    
    plt.figure(figsize=(8,6)) 
    plt.title('loss (K=4)')

    plt.plot(loss_iteration_04, '-', color='red')
    plt.xlabel('iteration')
    plt.ylabel('loss')
    
    plt.tight_layout()
    plt.show()

# %%
def function_result_07():
    
    plt.figure(figsize=(8,6))
    plt.title('loss (K=8)')

    plt.plot(loss_iteration_08, '-', color='red')
    plt.xlabel('iteration')
    plt.ylabel('loss')
    
    plt.tight_layout()
    plt.show()

# %%
def function_result_08():
    
    plt.figure(figsize=(8,6))
    plt.title('loss (K=16)')

    plt.plot(loss_iteration_16, '-', color='red')
    plt.xlabel('iteration')
    plt.ylabel('loss')
    
    plt.tight_layout()
    plt.show()

# %%
def function_result_09():

    plt.figure(figsize=(8,8))
    plt.title('centroid (K=2)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    colors = np.random.rand(len(centroid_iteration_02[0]), 3)
        
    for i in range(len(centroid_iteration_02[0]) - 1):
        plt.plot(centroid_iteration_02[:,i,0], centroid_iteration_02[:,i,1], '-', c = colors[i], label = "cluster=" + str(i))
        plt.plot(centroid_iteration_02[0,i,0], centroid_iteration_02[0,i,1], marker = 'o', color = 'blue')
        plt.plot(centroid_iteration_02[len(centroid_iteration_02) - 1,i,0], centroid_iteration_02[len(centroid_iteration_02) - 1,i,1], marker = 's', color = 'red')
    
    plt.plot(centroid_iteration_02[0,len(centroid_iteration_02[0]) - 1,0], centroid_iteration_02[0,len(centroid_iteration_02[0]) - 1,1], 'bo', label = "initial")
    plt.plot(centroid_iteration_02[len(centroid_iteration_02) - 1,len(centroid_iteration_02[0]) - 1,0], centroid_iteration_02[len(centroid_iteration_02) - 1,len(centroid_iteration_02[0]) - 1,1], 's', color = 'red', label = "final")
    
    plt.legend()
    plt.tight_layout()
    plt.show()

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_10():

    plt.figure(figsize=(8,8))
    plt.title('centroid (K=4)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    colors = np.random.rand(len(centroid_iteration_04[0]), 3)
        
    for i in range(len(centroid_iteration_04[0]) - 1):
        plt.plot(centroid_iteration_04[:,i,0], centroid_iteration_04[:,i,1], '-', c = colors[i], label = "cluster=" + str(i))
        plt.plot(centroid_iteration_04[0,i,0], centroid_iteration_04[0,i,1], marker = 'o', color = 'blue')
        plt.plot(centroid_iteration_04[len(centroid_iteration_04) - 1,i,0], centroid_iteration_04[len(centroid_iteration_04) - 1,i,1], marker = 's', color = 'red')
    
    plt.plot(centroid_iteration_04[0,len(centroid_iteration_04[0]) - 1,0], centroid_iteration_04[0,len(centroid_iteration_04[0]) - 1,1], 'bo', label = "initial")
    plt.plot(centroid_iteration_04[len(centroid_iteration_04) - 1,len(centroid_iteration_04[0]) - 1,0], centroid_iteration_04[len(centroid_iteration_04) - 1,len(centroid_iteration_04[0]) - 1,1], 's', color = 'red', label = "final")
    
    plt.legend()
    plt.tight_layout()
    plt.show()

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_11():

    plt.figure(figsize=(8,8))
    plt.title('centroid (K=8)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    colors = np.random.rand(len(centroid_iteration_08[0]), 3)
        
    for i in range(len(centroid_iteration_08[0]) - 1):
        plt.plot(centroid_iteration_08[:,i,0], centroid_iteration_08[:,i,1], '-', c = colors[i], label = "cluster=" + str(i))
        plt.plot(centroid_iteration_08[0,i,0], centroid_iteration_08[0,i,1], marker = 'o', color = 'blue')
        plt.plot(centroid_iteration_08[len(centroid_iteration_08) - 1,i,0], centroid_iteration_08[len(centroid_iteration_08) - 1,i,1], marker = 's', color = 'red')
    
    plt.plot(centroid_iteration_08[0,len(centroid_iteration_08[0]) - 1,0], centroid_iteration_08[0,len(centroid_iteration_08[0]) - 1,1], 'bo', label = "initial")
    plt.plot(centroid_iteration_08[len(centroid_iteration_08) - 1,len(centroid_iteration_08[0]) - 1,0], centroid_iteration_08[len(centroid_iteration_08) - 1,len(centroid_iteration_08[0]) - 1,1], 's', color = 'red', label = "final")
    
    plt.legend()
    plt.tight_layout()
    plt.show()

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_12():

    plt.figure(figsize=(8,8))
    plt.title('centroid (K=16)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    colors = np.random.rand(len(centroid_iteration_16[0]), 3)
        
    for i in range(len(centroid_iteration_16[0]) - 1):
        plt.plot(centroid_iteration_16[:,i,0], centroid_iteration_16[:,i,1], '-', c = colors[i], label = "cluster=" + str(i))
        plt.plot(centroid_iteration_16[0,i,0], centroid_iteration_16[0,i,1], marker = 'o', color = 'blue')
        plt.plot(centroid_iteration_16[len(centroid_iteration_16) - 1,i,0], centroid_iteration_16[len(centroid_iteration_16) - 1,i,1], marker = 's', color = 'red')
    
    plt.plot(centroid_iteration_16[0,len(centroid_iteration_16[0]) - 1,0], centroid_iteration_16[0,len(centroid_iteration_16[0]) - 1,1], 'bo', label = "initial")
    plt.plot(centroid_iteration_16[len(centroid_iteration_16) - 1,len(centroid_iteration_16[0]) - 1,0], centroid_iteration_16[len(centroid_iteration_16) - 1,len(centroid_iteration_16[0]) - 1,1], 's', color = 'red', label = "final")
    
    plt.legend()
    plt.tight_layout()
    plt.show()

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_13():

    plt.figure(figsize=(8,8))
    plt.title('cluster (K=2)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    x = feature[:,0]
    y = feature[:,1]
    
    plt.scatter(x, y, marker = 'o', c = label_feature_02, cmap = "rainbow")

    plt.colorbar(ticks = range(3), boundaries = np.arange(-0.5, 2, 1), label = "cluster")
    plt.tight_layout()
    plt.show()

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_14():

    plt.figure(figsize=(8,8))
    plt.title('cluster (K=4)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    x = feature[:,0]
    y = feature[:,1]
    
    plt.scatter(x, y, marker = 'o', c = label_feature_04, cmap = "rainbow")

    plt.colorbar(ticks = range(5), boundaries = np.arange(-0.5, 4, 1), label = "cluster")
    plt.tight_layout()
    plt.show()

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_15():

    plt.figure(figsize=(8,8))
    plt.title('cluster (K=8)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    x = feature[:,0]
    y = feature[:,1]
    
    plt.scatter(x, y, marker = 'o', c = label_feature_08, cmap = "rainbow")

    plt.colorbar(ticks = range(9), boundaries = np.arange(-0.5, 8, 1), label = "cluster")
    plt.tight_layout()
    plt.show()

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_16():

    plt.figure(figsize=(8,8))
    plt.title('cluster (K=16)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #

    x = feature[:,0]
    y = feature[:,1]
    
    plt.scatter(x, y, marker = 'o', c = label_feature_16, cmap = "rainbow")

    plt.colorbar(ticks = range(17), boundaries = np.arange(-0.5, 16, 1), label = "cluster")
    plt.tight_layout()
    plt.show()
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## results

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
number_result = 16

for i in range(number_result):
    title = '## [RESULT {:02d}]'.format(i+1)
    name_function = 'function_result_{:02d}()'.format(i+1)

    print('**************************************************')
    print(title)
    print('**************************************************')
    eval(name_function)
# Out:
# **************************************************
# ## [RESULT 01]
# **************************************************
# final loss (K=2) = 31.1126288111
# **************************************************
# ## [RESULT 02]
# **************************************************
# final loss (K=4) = 10.5831291650
# **************************************************
# ## [RESULT 03]
# **************************************************
# final loss (K=8) =  5.6797673688
# **************************************************
# ## [RESULT 04]
# **************************************************
# final loss (K=16) =  3.2544899281
# **************************************************
# ## [RESULT 05]
# **************************************************
# **************************************************
# ## [RESULT 06]
# **************************************************
# **************************************************
# ## [RESULT 07]
# ...
